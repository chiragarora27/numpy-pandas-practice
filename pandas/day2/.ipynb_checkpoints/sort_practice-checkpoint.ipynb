# %%
people = {
    "first" : ["Chirag", "Sahil", "Yana"],
    "last" : ["Arora", "Arora", "Bindal"],
    "email" : ["chiragarora@email.com", "sahilarora@email.com", "yanabindal@email.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#     first    last                  email
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Yana  Bindal   yanabindal@email.com

# %%
df.sort_values(by='last', ascending=False, inplace=True)

# %%
df
# Out:
#     first    last                  email
# 2    Yana  Bindal   yanabindal@email.com
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=False, inplace=True)

# %%
df
# Out:
#     first    last                  email
# 2    Yana  Bindal   yanabindal@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 0  Chirag   Arora  chiragarora@email.com

# %%
df.sort_index()
# Out:
#     first    last                  email
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Yana  Bindal   yanabindal@email.com

# %%
df['last'].sort_values()
# Out:
# 1     Arora
# 0     Arora
# 2    Bindal
# Name: last, dtype: str
