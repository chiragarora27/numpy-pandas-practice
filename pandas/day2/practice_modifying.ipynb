# %%
people = {
    "first" : ["Chirag", "Sahil", "Yana"],
    "last" : ["Arora", "Arora", "Bindal"],
    "email" : ["chiragarora@email.com", "sahilarora@email.com", "yanabindal@email.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#     first    last                  email
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Yana  Bindal   yanabindal@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.columns = ['first_name', 'last_name', 'email_id']
df.columns
# Out:
# Index(['first_name', 'last_name', 'email_id'], dtype='str')

# %%
df
# Out:
#   first_name last_name               email_id
# 0     Chirag     Arora  chiragarora@email.com
# 1      Sahil     Arora   sahilarora@email.com
# 2       Yana    Bindal   yanabindal@email.com

# %%
df.columns = [str.upper(string) for string in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME               EMAIL_ID
# 0     Chirag     Arora  chiragarora@email.com
# 1      Sahil     Arora   sahilarora@email.com
# 2       Yana    Bindal   yanabindal@email.com

# %%
df.columns = df.columns.str.replace('_', ' ')

# %%
df.columns
# Out:
# Index(['FIRST NAME', 'LAST NAME', 'EMAIL ID'], dtype='str')

# %%
df
# Out:
#   FIRST NAME LAST NAME               EMAIL ID
# 0     Chirag     Arora  chiragarora@email.com
# 1      Sahil     Arora   sahilarora@email.com
# 2       Yana    Bindal   yanabindal@email.com

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email_id'], dtype='str')

# %%
df.rename (columns = {'first_name' : 'first', 'last_name' : 'last'} ,  inplace = True)

# %%
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Yana  Bindal   yanabindal@email.com

# %%
df.loc[2]
# Out:
# first                       Yana
# last                      Bindal
# email_id    yanabindal@email.com
# Name: 2, dtype: str

# %%
df.loc[2] = ['Tana', 'Tindal', 'tanatindal@email.com']
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Tana  Tindal   tanatindal@email.com

# %%
df.loc[2, 'last'] = 'Bindal'
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Tana  Bindal   tanatindal@email.com

# %%
df.at[2, 'last'] = 'Tindal'
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Tana  Tindal   tanatindal@email.com

# %%
df.loc[0:1, 'email_id'] = df.loc[0:1, 'email_id'].str.upper()

# %%
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  CHIRAGARORA@EMAIL.COM
# 1   Sahil   Arora   SAHILARORA@EMAIL.COM
# 2    Tana  Tindal   tanatindal@email.com

# %%
df['email_id'] = df['email_id'].apply(str.upper)

# %%
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  CHIRAGARORA@EMAIL.COM
# 1   Sahil   Arora   SAHILARORA@EMAIL.COM
# 2    Tana  Tindal   TANATINDAL@EMAIL.COM

# %%
def lower_case(email):
    return email.lower()

# %%
df['email_id'] = df['email_id'].apply(lower_case)

# %%
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Tana  Tindal   tanatindal@email.com

# %%
df['email_id'] = df['email_id'].apply(lambda x: x.upper())

# %%
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  CHIRAGARORA@EMAIL.COM
# 1   Sahil   Arora   SAHILARORA@EMAIL.COM
# 2    Tana  Tindal   TANATINDAL@EMAIL.COM

# %%
df['email_id'] = df['email_id'].apply(lambda x: x.lower())

# %%
df.map(str.lower)
# Out:
#     first    last               email_id
# 0  chirag   arora  chiragarora@email.com
# 1   sahil   arora   sahilarora@email.com
# 2    tana  tindal   tanatindal@email.com

# %%
df.map(len)
# Out:
#    first  last  email_id
# 0      6     5        21
# 1      5     5        20
# 2      4     6        20

# %%
df['first'] = ['Chirag', 'Sahil', 'Yana']

# %%
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Yana  Tindal   tanatindal@email.com

# %%
df['first'].map({'Chirag' : 'Tilag', 'Sahil' : 'Tahil'})
# Out:
# 0    Tilag
# 1    Tahil
# 2      NaN
# Name: first, dtype: str

# %%
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Yana  Tindal   tanatindal@email.com

# %%
df['first'].replace({'Chirag' : 'Tilag', 'Sahil' : 'Tahil'})
# Out:
# 0    Tilag
# 1    Tahil
# 2     Yana
# Name: first, dtype: str

# %%
df
# Out:
#     first    last               email_id
# 0  Chirag   Arora  chiragarora@email.com
# 1   Sahil   Arora   sahilarora@email.com
# 2    Yana  Tindal   tanatindal@email.com

# %%
df['first'] = df['first'].replace({'Chirag' : 'Tilag', 'Sahil' : 'Tahil'})

# %%
df
# Out:
#    first    last               email_id
# 0  Tilag   Arora  chiragarora@email.com
# 1  Tahil   Arora   sahilarora@email.com
# 2   Yana  Tindal   tanatindal@email.com

# %%
df
# Out:
#    first    last               email_id    full_name
# 0  Tilag   Arora  chiragarora@email.com  Tilag Arora
# 1  Tahil   Arora   sahilarora@email.com  Tahil Arora
# 2   Yana  Tindal   tanatindal@email.com  Yana Tindal

# %%
df['first'] = df['first'].replace({'Tilag' : 'Chirag', 'Tahil': 'Sahil'})

# %%
df['last'] = df['last'].replace({'Tindal' : 'Bindal'})

# %%
df
# Out:
#     first    last               email_id    full_name
# 0  Chirag   Arora  chiragarora@email.com  Tilag Arora
# 1   Sahil   Arora   sahilarora@email.com  Tahil Arora
# 2    Yana  Bindal   tanatindal@email.com  Yana Tindal

# %%
# adding columns

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#     first    last               email_id     full_name
# 0  Chirag   Arora  chiragarora@email.com  Chirag Arora
# 1   Sahil   Arora   sahilarora@email.com   Sahil Arora
# 2    Yana  Bindal   tanatindal@email.com   Yana Bindal

# %%
# removing columns

# %%
df.drop(columns = ['first', 'last'], inplace=True)

# %%
df
# Out:
#                 email_id     full_name
# 0  chiragarora@email.com  Chirag Arora
# 1   sahilarora@email.com   Sahil Arora
# 2   tanatindal@email.com   Yana Bindal

# %%
tf = df['full_name'].str.split(' ', expand=True)

# %%
tf
# Out:
#         0       1
# 0  Chirag   Arora
# 1   Sahil   Arora
# 2    Yana  Bindal

# %%
df[['first', 'last']] = tf

# %%
df
# Out:
#                 email_id     full_name   first   lasst    last
# 0  chiragarora@email.com  Chirag Arora  Chirag   Arora   Arora
# 1   sahilarora@email.com   Sahil Arora   Sahil   Arora   Arora
# 2   tanatindal@email.com   Yana Bindal    Yana  Bindal  Bindal

# %%
df.drop(columns='lasst', inplace=True)

# %%
df
# Out:
#                 email_id     full_name   first    last
# 0  chiragarora@email.com  Chirag Arora  Chirag   Arora
# 1   sahilarora@email.com   Sahil Arora   Sahil   Arora
# 2   tanatindal@email.com   Yana Bindal    Yana  Bindal
