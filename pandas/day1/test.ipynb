# %%
people = {
    'first': ["Chirag", "Sahil", "Yana"],
    'last': ["Arora", "Arora", "Bindal"],
    'email': ["chiragarora@email.com", "sahilarora@email.com", "yanabindal@email.com"],
    'count': [100, 101, 102]
}

# %%
people
# Out:
# {'first': ['Chirag', 'Sahil', 'Yana'],
#  'last': ['Arora', 'Arora', 'Bindal'],
#  'email': ['chiragarora@email.com',
#   'sahilarora@email.com',
#   'yanabindal@email.com'],
#  'count': [100, 101, 102]}

# %%
people['email']
# Out:
# ['chiragarora@email.com', 'sahilarora@email.com', 'yanabindal@email.com']

# %%
people['first']
# Out:
# ['Chirag', 'Sahil', 'Yana']

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#     first    last                  email  count
# 0  Chirag   Arora  chiragarora@email.com    100
# 1   Sahil   Arora   sahilarora@email.com    101
# 2    Yana  Bindal   yanabindal@email.com    102

# %%
df['email']
# Out:
# 0    chiragarora@email.com
# 1     sahilarora@email.com
# 2     yanabindal@email.com
# Name: email, dtype: str

# %%
df.email
# Out:
# 0    chiragarora@email.com
# 1     sahilarora@email.com
# 2     yanabindal@email.com
# Name: email, dtype: str

# %%
df['email']
# Out:
# 0    chiragarora@email.com
# 1     sahilarora@email.com
# 2     yanabindal@email.com
# Name: email, dtype: str

# %%
type(df['email'])
# Out:
# pandas.Series

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df[['last' , 'email']]
# Out:
#      last                  email
# 0   Arora  chiragarora@email.com
# 1   Arora   sahilarora@email.com
# 2  Bindal   yanabindal@email.com

# %%
df.count
# Out:
# <bound method DataFrame.count of     first    last                  email  count
# 0  Chirag   Arora  chiragarora@email.com    100
# 1   Sahil   Arora   sahilarora@email.com    101
# 2    Yana  Bindal   yanabindal@email.com    102>

# %%
df['count']
# Out:
# 0    100
# 1    101
# 2    102
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['first', 'last', 'email', 'count'], dtype='str')

# %%
df.iloc[0]
# Out:
# first                   Chirag
# last                     Arora
# email    chiragarora@email.com
# count                      100
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# first                   Sahil
# last                    Arora
# email    sahilarora@email.com
# count                     101
# Name: 1, dtype: object

# %%
df.iloc[[1,2]]
# Out:
#    first    last                 email  count
# 1  Sahil   Arora  sahilarora@email.com    101
# 2   Yana  Bindal  yanabindal@email.com    102

# %%
df.iloc[[1,2] , 2]
# Out:
# 1    sahilarora@email.com
# 2    yanabindal@email.com
# Name: email, dtype: str

# %%
df
# Out:
#     first    last                  email  count
# 0  Chirag   Arora  chiragarora@email.com    100
# 1   Sahil   Arora   sahilarora@email.com    101
# 2    Yana  Bindal   yanabindal@email.com    102

# %%
df.loc[0] # - right now same as iloc since there are no specific index labels, the indexes are just labeles : 0, 1, 2,.....
# Out:
# first                   Chirag
# last                     Arora
# email    chiragarora@email.com
# count                      100
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#     first   last                  email  count
# 0  Chirag  Arora  chiragarora@email.com    100
# 1   Sahil  Arora   sahilarora@email.com    101

# %%
df.loc[[0,1], 'email']
# Out:
# 0    chiragarora@email.com
# 1     sahilarora@email.com
# Name: email, dtype: str

# %%
df.loc[[0,1], ['first', 'last']]
# Out:
#     first   last
# 0  Chirag  Arora
# 1   Sahil  Arora

# %%
df.loc[[0,1], ['last','first']]
# Out:
#     last   first
# 0  Arora  Chirag
# 1  Arora   Sahil

# %%
df
# Out:
#     first    last                  email  count
# 0  Chirag   Arora  chiragarora@email.com    100
# 1   Sahil   Arora   sahilarora@email.com    101
# 2    Yana  Bindal   yanabindal@email.com    102

# %%
df = df.reset_index()

# %%
df
# Out:
#                    email   first    last  count
# 0  chiragarora@email.com  Chirag   Arora    100
# 1   sahilarora@email.com   Sahil   Arora    101
# 2   yanabindal@email.com    Yana  Bindal    102

# %%
df.set_index('email')
# Out:
#                         first    last  count
# email
# chiragarora@email.com  Chirag   Arora    100
# sahilarora@email.com    Sahil   Arora    101
# yanabindal@email.com     Yana  Bindal    102

# %%
df
# Out:
#                    email   first    last  count
# 0  chiragarora@email.com  Chirag   Arora    100
# 1   sahilarora@email.com   Sahil   Arora    101
# 2   yanabindal@email.com    Yana  Bindal    102

# %%
df = df.set_index('email')

# %%
df
# Out:
#                         first    last  count
# email
# chiragarora@email.com  Chirag   Arora    100
# sahilarora@email.com    Sahil   Arora    101
# yanabindal@email.com     Yana  Bindal    102

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                         first    last  count
# email
# chiragarora@email.com  Chirag   Arora    100
# sahilarora@email.com    Sahil   Arora    101
# yanabindal@email.com     Yana  Bindal    102

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.set_index('email', inplace= True)

# %%
df
# Out:
#                         first    last  count
# email
# chiragarora@email.com  Chirag   Arora    100
# sahilarora@email.com    Sahil   Arora    101
# yanabindal@email.com     Yana  Bindal    102

# %%
df.index
# Out:
# Index(['chiragarora@email.com', 'sahilarora@email.com',
#        'yanabindal@email.com'],
#       dtype='str', name='email')

# %%
df.loc[['sahilarora@email.com', 'yanabindal@email.com'], ['last']]
# Out:
#                         last
# email
# sahilarora@email.com   Arora
# yanabindal@email.com  Bindal

# %%
df.loc['sahilarora@email.com', 'last']
# Out:
# 'Arora'

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.iloc[0]
# Out:
# first    Chirag
# last      Arora
# count       100
# Name: chiragarora@email.com, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#                    email   first    last  count
# 0  chiragarora@email.com  Chirag   Arora    100
# 1   sahilarora@email.com   Sahil   Arora    101
# 2   yanabindal@email.com    Yana  Bindal    102

# %%
df['last'] == 'Arora'
# Out:
# 0     True
# 1     True
# 2    False
# Name: last, dtype: bool

# %%
filt = ( df['last'] == 'Arora' )

# %%
filt
# Out:
# 0     True
# 1     True
# 2    False
# Name: last, dtype: bool

# %%
type(filt)
# Out:
# pandas.Series

# %%
df[filt]
# Out:
#                    email   first   last  count
# 0  chiragarora@email.com  Chirag  Arora    100
# 1   sahilarora@email.com   Sahil  Arora    101

# %%
df[df['last'] == 'Arora']
# Out:
#                    email   first   last  count
# 0  chiragarora@email.com  Chirag  Arora    100
# 1   sahilarora@email.com   Sahil  Arora    101

# %%
df.loc[filt]
# Out:
#                    email   first   last  count
# 0  chiragarora@email.com  Chirag  Arora    100
# 1   sahilarora@email.com   Sahil  Arora    101

# %%
df.loc[filt, 'count']
# Out:
# 0    100
# 1    101
# Name: count, dtype: int64

# %%
filt2 = (df['last'] == 'Arora') & (df['first'] == 'Sahil')

# %%
df.loc[filt2]
# Out:
#                   email  first   last  count
# 1  sahilarora@email.com  Sahil  Arora    101

# %%
filt3 = (df['last'] == 'Arora') | (df['first'] == 'Yana')

# %%
df.loc[filt3]
# Out:
#                    email   first    last  count
# 0  chiragarora@email.com  Chirag   Arora    100
# 1   sahilarora@email.com   Sahil   Arora    101
# 2   yanabindal@email.com    Yana  Bindal    102

# %%
df.loc[~filt3]
# Out:
# Empty DataFrame
# Columns: [email, first, last, count]
# Index: []
