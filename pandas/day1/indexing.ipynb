# %%
import pandas as pd

# %%
df = pd.read_csv('data1.csv', index_col = 'show_id')

# %%
df
# Out:
#             type                                   title            director  \
# show_id
# 33238    TV Show                             Running Man                 안재철
# 32415    TV Show                                   Conan                 NaN
# 37757    TV Show                       MasterChef Greece                 NaN
# 75685    TV Show                              Prostřeno!                 NaN
# 33847    TV Show                                The Talk                 NaN
# ...          ...                                     ...                 ...
# 284892   TV Show                              Sammelanam                 NaN
# 277665   TV Show                            Anne Shirley                 NaN
# 284972   TV Show                     Le onde del passato  Giulio Manfredonia
# 284613   TV Show                                 AI히치하이커                 NaN
# 251815   TV Show  Alex & Laura's Saturday Night Takeaway                 NaN
#
# ...

# %%
df.loc[75685]
# Out:
# type                                                      TV Show
# title                                                  Prostřeno!
# director                                                      NaN
# cast                                  Václav Vydra, Jana Boušková
# country                                            Czech Republic
# date_added                                             2010-03-01
# release_year                                                 2010
# rating                                                        6.5
# duration                                                1 Seasons
# genres                                                    Reality
# language                                                       cs
# description     The knives (and forks) are out as a group of s...
# popularity                                               1095.776
# vote_count                                                      6
# ...

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#             type                         title      director  \
# show_id
# 767      TV Show             Ready Steady Cook  Julian Smith
# 877      TV Show                       Caprica           NaN
# 1399     TV Show               Game of Thrones           NaN
# 1401     TV Show                Hell on Wheels           NaN
# 1402     TV Show              The Walking Dead           NaN
# ...          ...                           ...           ...
# 285310   TV Show  Number One on the Call Sheet           NaN
# 285311   TV Show              مومولو والأصدقاء           NaN
# 285314   TV Show                           SC+           NaN
# 285315   TV Show                        深深爸讲乐理           NaN
# 285345   TV Show                 Love Suddenly           NaN
#
#                                                       cast  \
# show_id
# 767                                            Rylan Clark
# 877      Eric Stoltz, Esai Morales, Paula Malcomson, Al...
# ...
