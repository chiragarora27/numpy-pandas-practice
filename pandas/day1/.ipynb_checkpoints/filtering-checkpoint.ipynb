# %%
import pandas as pd

# %%
df = pd.read_csv('data1.csv', index_col = 'show_id')

# %%
df.head()
# Out:
#             type              title director  \
# show_id
# 33238    TV Show        Running Man      안재철
# 32415    TV Show              Conan      NaN
# 37757    TV Show  MasterChef Greece      NaN
# 75685    TV Show         Prostřeno!      NaN
# 33847    TV Show           The Talk      NaN
#
#                                                       cast  \
# show_id
# 33238    Yoo Jae-suk, Jee Seok-jin, Kim Jong-kook, Haha...
# 32415                          Conan O'Brien, Andy Richter
# 37757                                                  NaN
# 75685                          Václav Vydra, Jana Boušková
# 33847    Amanda Kloots, Jerry O'Connell, Akbar Gbaja-Bi...
#
#                                    country  date_added  release_year  rating  \
# show_id
# 33238                          South Korea  2010-07-11          2010   8.241
# 32415             United States of America  2010-11-08          2010   7.035
# ...

# %%
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'language',
#        'description', 'popularity', 'vote_count', 'vote_average'],
#       dtype='str')

# %%
high_rating = (df['rating'] > 8)

# %%
df.loc[high_rating, ['director', 'country', 'genres']].value_counts('country').head(15)
# Out:
# country
# Japan                       410
# China                       367
# United States of America    335
# South Korea                 269
# Thailand                     62
# Russia                       60
# Turkey                       58
# United Kingdom               56
# India                        50
# France                       42
# Brazil                       42
# Pakistan                     42
# Germany                      39
# Canada                       36
# Philippines                  33
# Name: count, dtype: int64

# %%
df.loc[high_rating, ['director', 'country', 'genres']].value_counts('director').head(15)
# Out:
# director
# Yu Je-won              5
# Haissam Hussain        4
# Oh Choong-hwan         4
# Song Hyun-wook         4
# Lee Jung-sub           3
# Dominic Zapata         3
# Jung Dae-yoon          3
# Siwaj Sawatmaneekul    3
# An Jian                3
# An Gil-ho              3
# Akira Nishimori        2
# Jiang Liu              2
# Hong Chang-wook        2
# Mehreen Jabbar         2
# Kim Sok-yun            2
# Name: count, dtype: int64

# %%
df.loc[high_rating, ['director', 'country', 'genres']].value_counts('genres').head(15)
# Out:
# genres
# Drama                                              400
# Reality                                            168
# Comedy                                             139
# Comedy, Drama                                       94
# Documentary                                         90
# Drama, Comedy                                       74
# Animation, Comedy                                   67
# Animation, Action & Adventure, Sci-Fi & Fantasy     44
# Talk                                                43
# Drama, Family                                       36
# Drama, Crime                                        35
# Crime, Drama                                        34
# Animation, Comedy, Drama                            28
# Drama, Mystery                                      24
# Animation, Sci-Fi & Fantasy, Action & Adventure     23
# Name: count, dtype: int64

# %%
df.loc[high_rating, ['director', 'country', 'genres', 'rating']]
# Out:
#                    director                          country  \
# show_id
# 33238                   안재철                      South Korea
# 1402                    NaN         United States of America
# 31132                   NaN         United States of America
# 33581                   NaN  India, United States of America
# 46296                   NaN         United States of America
# ...                     ...                              ...
# 281061                  NaN         United States of America
# 284533                  NaN                          Denmark
# 285281                  NaN                          Denmark
# 285202                  NaN                              NaN
# 284972   Giulio Manfredonia                              NaN
#
#                                               genres  rating
# show_id
# 33238                                Comedy, Reality   8.241
# 1402     Action & Adventure, Drama, Sci-Fi & Fantasy   8.103
# ...

# %%
countries = ['United States of America', 'India', 'Canada', 'China', 'Japan']

# %%
new_filt = df['country'].isin(countries)

# %%
df.loc[new_filt, 'country']
# Out:
# show_id
# 32415     United States of America
# 1402      United States of America
# 33384     United States of America
# 31132     United States of America
# 64488                       Canada
#                     ...
# 262700                       Japan
# 281309                       India
# 279206                       China
# 273517                       China
# 277665                       Japan
# Name: country, Length: 6620, dtype: str

# %%
filt_new = df['genres'].str.contains('Comedy', na=False)

# %%
df.loc[filt_new, 'genres']
# Out:
# show_id
# 33238        Comedy, Reality
# 32415     Talk, Comedy, News
# 31132      Animation, Comedy
# 51038           Comedy, Talk
# 32651                 Comedy
#                  ...
# 280890         Drama, Comedy
# 285202        Comedy, Family
# 284082                Comedy
# 284892         Comedy, Drama
# 251815        Comedy, Family
# Name: genres, Length: 4576, dtype: str
